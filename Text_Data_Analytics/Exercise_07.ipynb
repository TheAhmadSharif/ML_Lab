# %%
import gym
import numpy as np
import itertools
env = gym.make("FrozenLake-v1", is_slippery=False)
env.reset()
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
state, reward, done, info = env.step(1)
env.render()
# Out:
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
