# %%
# Exercise 1.4: Python basics, part 1.
# Ahmad Sharif
# Student ID : K 436765

# %%
from scipy.stats import multivariate_normal
import numpy as np
# Out:
# 0.0013717986904768747

# %%
multivariate_normal.pdf(x = [2,2,2], mean=[1,3,5], cov=[[4,2,1],
[2,5,2],
[1,2,3]])
# Out:
# 0.0013717986904768747

# %%
multivariate_normal.pdf(x = [1,4,3], mean=[1,3,5], cov=[[4,2,1],
[2,5,2],
[1,2,3]])
# Out:
# 0.0026090337298477584

# %%
multivariate_normal.pdf(x = [1,1,5], mean=[1,3,5], cov=[[4,2,1],
[2,5,2],
[1,2,3]])
# Out:
# 0.005724150877228364
