# %%
# Date: 12 Febraury 2024
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import seaborn as sns

dataset = pd.read_csv("datasets/H_W_Gender.csv")
dataset = dataset[(dataset["Height"] < 200) & (dataset["Weight"] < 200)]

dataset.describe()

x = dataset.iloc[:, [0,1]].values
y = dataset.iloc[:, 2].values

x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.30, random_state = 3)  



knn = KNeighborsClassifier(n_neighbors = 6, metric='minkowski', p = 2 )  
knn.fit(x_train, y_train)  
y_pred= knn.predict(x_test)  

confusion_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix
print(accuracy_score(y_test,y_pred))

                          
knn.predict([ [170, 84]])
# Out:
#             Height       Weight
# count  2993.000000  2993.000000
# mean    160.323702    68.234056
# std      15.158649    15.216433
# min      25.680000     8.530000
# 25%     149.480000    57.930000
# 50%     160.860000    67.350000
# 75%     171.590000    77.880000
# max     199.860000   121.980000
# KNeighborsClassifier(n_neighbors=6)
# array([[382,  58],
#        [ 89, 369]])
# 0.8363028953229399
# array(['Male'], dtype=object)

# %%
# len(x)
# len(y)

plt.scatter(dataset["Height"], dataset["Weight"])

# %%
sns.scatterplot(x = 'Height', y = 'Weight', data=dataset) 
plt.figure(figsize=(20, 20))
plt.show()
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
# sns.rerplot(data=dataset[:500], x="Height", y="Weight", hue="Sex") # Rel plot : Relation Plot

ax = sns.scatterplot(data=dataset[:500], x="Height", y="Weight", hue="Sex", palette="deep", marker="o",
    sizes=(20, 200), legend="full")
 
ax.plot(130, 60, marker="*", color="r", markersize=20)

plt.show()
