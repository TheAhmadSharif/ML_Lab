# %%
import pandas as pd
# Out:
# 1.4.2

# %%
# Data Type
dataset = {
    "cars": ["Toyota", "BMW"],
    "engine": 2
}
var_data = pd.DataFrame(dataset)

print(var_data)
# Out:
#      cars  engine
# 0  Toyota       2
# 1     BMW       2

# %%
dats_series = [1,2,4]
pd.Series(dats_series)
# Out:
# 0    1
# 1    2
# 2    4
# dtype: int64

# %%
pd.options.display.max_rows = 9999

df = pd.read_csv('~/Desktop/data.txt')
print(df)
# Out:
# Empty DataFrame
# Columns: [Abir,  25]
# Index: []
