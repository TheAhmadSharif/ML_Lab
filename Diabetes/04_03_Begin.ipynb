# %% [markdown]
# ## Dataset and Library
# The dataset that will be used as a sample in this notebook is the [Drug Review Dataset](https://archive.ics.uci.edu/ml/datasets/Drug+Review+Dataset+%28Drugs.com%29) from the open source UCI Machine Learning Repository and the python [scattertext](https://github.com/JasonKessler/scattertext) library

# %% [markdown]
# ##Data preprocessing

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip
# Out:
# --2023-03-02 13:51:55--  https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42989872 (41M) [application/x-httpd-php]
# Saving to: ‘drugsCom_raw.zip’
#
# drugsCom_raw.zip    100%[===================>]  41.00M  30.1MB/s    in 1.4s
#
# 2023-03-02 13:51:56 (30.1 MB/s) - ‘drugsCom_raw.zip’ saved [42989872/42989872]

# %%
# !unzip drugsCom_raw.zip
# Out:
# Archive:  drugsCom_raw.zip
#   inflating: drugsComTest_raw.tsv
#   inflating: drugsComTrain_raw.tsv

# %%
# %%capture
# !pip install scattertext

# %%
import pandas as pd
from wordcloud import WordCloud
import spacy
import scattertext as st
import matplotlib.pyplot as plt
from IPython.display import IFrame
from IPython.core.display import display, HTML
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
df1 = pd.read_csv('drugsComTest_raw.tsv',delimiter='\t')   
df2 = pd.read_csv('drugsComTrain_raw.tsv', delimiter='\t')
medication_reviews_df = pd.concat([df1,df2])

# %%
medication_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 215063 entries, 0 to 161296
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   215063 non-null  int64
#  1   drugName     215063 non-null  object
#  2   condition    213869 non-null  object
#  3   review       215063 non-null  object
#  4   rating       215063 non-null  float64
#  5   date         215063 non-null  object
#  6   usefulCount  215063 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 13.1+ MB

# %%
medication_reviews_df.rename(columns={"Unnamed: 0": "uniqueId"},inplace=True)

# %%
medication_reviews_df
# Out:
#         uniqueId            drugName                     condition  \
# 0         163740         Mirtazapine                    Depression
# 1         206473          Mesalamine  Crohn's Disease, Maintenance
# 2         159672             Bactrim       Urinary Tract Infection
# 3          39293            Contrave                   Weight Loss
# 4          97768     Cyclafem 1 / 35                 Birth Control
# ...          ...                 ...                           ...
# 161292    191035             Campral            Alcohol Dependence
# 161293    127085      Metoclopramide               Nausea/Vomiting
# 161294    187382             Orencia          Rheumatoid Arthritis
# 161295     47128  Thyroid desiccated           Underactive Thyroid
# 161296    215220        Lubiprostone         Constipation, Chronic
#
#                                                    review  rating  \
# 0       "I&#039;ve tried a few antidepressants over th...    10.0
# ...

# %%
medication_reviews_df[:50]
# Out:
#     uniqueId                          drugName                     condition  \
# 0     163740                       Mirtazapine                    Depression
# 1     206473                        Mesalamine  Crohn's Disease, Maintenance
# 2     159672                           Bactrim       Urinary Tract Infection
# 3      39293                          Contrave                   Weight Loss
# 4      97768                   Cyclafem 1 / 35                 Birth Control
# 5     208087                           Zyclara                     Keratosis
# 6     215892                            Copper                 Birth Control
# 7     169852                     Amitriptyline           Migraine Prevention
# 8      23295                         Methadone             Opiate Withdrawal
# 9      71428                            Levora                 Birth Control
# 10    196802                        Paroxetine                   Hot Flashes
# ...

# %%
medication_reviews_df['date'].min()
# Out:
# 'April 1, 2008'

# %%
medication_reviews_df['date'].max()
# Out:
# 'September 9, 2017'

# %% [markdown]
# ##Diseases and Medications text visualization using WordClouds

# %%
all_drugs = medication_reviews_df['drugName'].to_string()
wordcloud = WordCloud().generate(all_drugs)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
all_conditions = medication_reviews_df['condition'].to_string()
wordcloud = WordCloud(background_color="white").generate(all_conditions)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ##Diseases and Medications text visualization using Scattertext

# %%
nlp = st.WhitespaceNLP.whitespace_nlp_with_sentences
corpus = st.CorpusFromPandas(medication_reviews_df,text_col='condition',category_col='drugName', nlp=nlp).build()

# %%
html = st.produce_scattertext_explorer(corpus,category='Metoclopramide',category_name='Metoclopramide',not_category_name='All others',width_in_pixels=1210,save_svg_button=True)

# %%
display(HTML(html))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
html2 = st.produce_scattertext_explorer(corpus,category='Ethinyl estradiol / etonogestrel',category_name='Ethinyl estradiol / etonogestrel',not_category_name='All others',width_in_pixels=1210,save_svg_button=True)

# %%
display(HTML(html2))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
