# %% [markdown]
#  Date: 12 February 2024
#  https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.show.html
# If you prefer precise control over plot aesthetics and are comfortable writing code, Matplotlib might be your choice. If you’re aiming for informative statistical plots with less effort, Seaborn could be the go-to. For interactive dashboards and web applications that engage users, Plotly offers a powerful solution.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

dataset = pd.read_csv("../datasets/H_W_Gender.csv")
dataset = dataset[(dataset["Height"] < 200) & (dataset["Weight"] < 200)]

dataset.describe()
# Out:
#             Height       Weight
# count  2993.000000  2993.000000
# mean    160.323702    68.234056
# std      15.158649    15.216433
# min      25.680000     8.530000
# 25%     149.480000    57.930000
# 50%     160.860000    67.350000
# 75%     171.590000    77.880000
# max     199.860000   121.980000

# %%
x = np.random.rand(1,2)
x
# Out:
# array([[0.66154511, 0.31870978]])

# %%
plt.plot([2,4], [4, 6], 'o:r')
plt.plot([2, 6, 9])
plt.hist([2, 4, 6])
plt.show() # Display all open figures.

# %%
# seaborn.lmplot() method is used to draw a scatter plot onto a FacetGrid.
# https://www.geeksforgeeks.org/python-seaborn-lmplot-method/

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.lmplot(data=dataset[:100], x="Height", y="Weight", hue="Sex", legend = "false", fit_reg = "false")

# %%
sns.relplot(data=dataset[:100], x="Height", y="Weight", hue="Sex") # Rel plot : Relation Plot

# %%
fig = px.box(dataset[1:3000], x="Height", y="Weight", color="Sex")
fig.show()
# Out:
# <div>                            <div id="b4924425-1e13-40e9-b908-3f1928a30f13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4924425-1e13-40e9-b908-3f1928a30f13")) {                    Plotly.newPlot(                        "b4924425-1e13-40e9-b908-3f1928a30f13",                        [{"alignmentgroup":"True","hovertemplate":"Sex=Female<br>Height=%{x}<br>Weight=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa"},"name":"Female","notched":false,"offsetgroup":"Female","orientation":"v","showlegend":true,"x":[148.53,143.05,149.16,155.8,145.37,142.03,150.17,137.1,149.42,147.33,138.9,129.27,173.64,144.58,124.37,140.42,165.09,138.09,141.31,156.92,135.28,145.79,142.89,159.81,130.32,135.27,146.8,133.58,165.85,155.24,159.07,147.64,
# ...
