# %%
# Date: 16 February 2025
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Dataset 2: Weight vs Height
data_height_weight = {
    "Height (inches)": [60, 62, 64, 66, 68, 70, 72, 74],
    "Weight (lbs)": [110, 120, 130, 140, 150, 160, 170, 180]
}

# Convert to DataFrames
df_study = pd.DataFrame(data_study)

# Plot Weight vs Height
plt.figure(figsize=(12, 5))
plt.scatter(df_height_weight["Height (inches)"], df_height_weight["Weight (lbs)"], color="blue")
plt.title("Weight vs Height")
plt.xlabel("Height (inches)")
plt.ylabel("Weight (lbs)")
# plt.grid(True)
plt.show()

# %%
import statsmodels.api as sm

# Add a constant term for the intercept
X = sm.add_constant(df_study["Study Hours"])
y = df_study["Exam Score"]

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Exam Score   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     113.7
# Date:                Sun, 16 Feb 2025   Prob (F-statistic):           4.01e-05
# Time:                        12:08:51   Log-Likelihood:                -22.274
# No. Observations:                   8   AIC:                             48.55
# Df Residuals:                       6   BIC:                             48.71
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          46.8929      3.524     13.307      0.000      38.270      55.516
# ...
