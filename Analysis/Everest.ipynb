# %%
# 25 May 2025

# %% [markdown]
# <h1 style="line-height:3rem;"> Everest Expeditions </h1>

# %%
import pandas as pd
import os

def load_everest_data():
    """
    Load Everest.csv from local or Kaggle environment.
    Returns:
        DataFrame: Everest expedition data.
    """
    env_name = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', 'Localhost')
    if env_name == "Localhost":
        df = pd.read_csv('../datasets/New/Everest_Expedition.csv', low_memory=False)
    else:
        df = pd.read_csv("/kaggle/input/everest-expedition/Everest_Expedition.csv", low_memory=False)
    return df

def top_n_national_success(df, top_n=10, include_countries=None):
    """
    Get top N nationalities by total successful summits, including specified countries.
    
    Args:
        df (DataFrame): Everest expedition data.
        top_n (int): Number of top nationalities to return.
        include_countries (list): List of countries to always include.
        
    Returns:
        DataFrame: Filtered and sorted nationality success DataFrame.
    """
    # Group by nation and sum successful summits
    nation_success = (
        df.groupby('nation')['smtmembers']
        .sum()
        .reset_index()
        .rename(columns={'nation': 'Nation', 'smtmembers': 'Total Successful Summits'})
    )
    
    # Sort and get top N
    top_df = nation_success.sort_values(by='Total Successful Summits', ascending=False).head(top_n)

    # Include specific countries even if not in top N
    if include_countries:
        include_countries_clean = [c.strip() for c in include_countries]
        extra_df = nation_success[nation_success['Nation'].isin(include_countries_clean)]
        combined_df = pd.concat([top_df, extra_df], ignore_index=True)
        combined_df = combined_df.drop_duplicates(subset='Nation')
        combined_df = combined_df.sort_values(by='Total Successful Summits', ascending=False).reset_index(drop=True)
    else:
        combined_df = top_df.reset_index(drop=True)

    return combined_df

def style_gradient_table(df):
    """
    Apply a gradient style to the Total Successful Summits column.
    
    Args:
        df (DataFrame): DataFrame of nationality success.
        
    Returns:
        Styler: Styled DataFrame.
    """
    return df.style.background_gradient(subset=['Total Successful Summits'], cmap='YlGnBu')

# Example usage
# Example usage
if __name__ == "__main__":
    df = load_everest_data()
    include_countries = ["Finland", "Bangladesh", "Pakistan"]
    top_n_df = top_n_national_success(df, top_n=40, include_countries=include_countries)

    # For Jupyter or Kaggle Notebooks, explicitly display the styled table
    from IPython.display import display
    styled_table = style_gradient_table(top_n_df)
    display(styled_table)
# Out:
# <style type="text/css">
# #T_ae572_row0_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_ae572_row1_col1 {
#   background-color: #2260a9;
#   color: #f1f1f1;
# }
# #T_ae572_row2_col1 {
#   background-color: #1f82b9;
#   color: #f1f1f1;
# }
# #T_ae572_row3_col1 {
#   background-color: #55bec1;
#   color: #000000;
# }
# #T_ae572_row4_col1 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_ae572_row5_col1 {
#   background-color: #65c3bf;
#   color: #000000;
# }
# #T_ae572_row6_col1 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_ae572_row7_col1 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_ae572_row8_col1 {
#   background-color: #aedfb6;
#   color: #000000;
# }
# #T_ae572_row9_col1 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_ae572_row10_col1 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_ae572_row11_col1, #T_ae572_row12_col1 {
#   background-color: #c8e9b4;
#   color: #000000;
# }
# #T_ae572_row13_col1, #T_ae572_row14_col1 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_ae572_row15_col1 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# #T_ae572_row16_col1 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_ae572_row17_col1 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_ae572_row18_col1 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_ae572_row19_col1 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_ae572_row20_col1 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_ae572_row21_col1 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_ae572_row22_col1 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_ae572_row23_col1 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_ae572_row24_col1 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_ae572_row25_col1 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_ae572_row26_col1 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_ae572_row27_col1, #T_ae572_row28_col1 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_ae572_row29_col1, #T_ae572_row30_col1, #T_ae572_row31_col1, #T_ae572_row32_col1, #T_ae572_row33_col1 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_ae572_row34_col1, #T_ae572_row35_col1, #T_ae572_row36_col1 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_ae572_row37_col1, #T_ae572_row38_col1 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_ae572_row39_col1, #T_ae572_row40_col1 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_ae572_row41_col1, #T_ae572_row42_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# </style>
# <table id="T_ae572">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae572_level0_col0" class="col_heading level0 col0" >Nation</th>
#       <th id="T_ae572_level0_col1" class="col_heading level0 col1" >Total Successful Summits</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae572_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae572_row0_col0" class="data row0 col0" >USA</td>
#       <td id="T_ae572_row0_col1" class="data row0 col1" >2950</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae572_row1_col0" class="data row1 col0" >UK</td>
#       <td id="T_ae572_row1_col1" class="data row1 col1" >2204</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae572_row2_col0" class="data row2 col0" >Japan</td>
#       <td id="T_ae572_row2_col1" class="data row2 col1" >1959</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae572_row3_col0" class="data row3 col0" >France</td>
#       <td id="T_ae572_row3_col1" class="data row3 col1" >1367</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae572_row4_col0" class="data row4 col0" >China</td>
#       <td id="T_ae572_row4_col1" class="data row4 col1" >1305</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ae572_row5_col0" class="data row5 col0" >Nepal</td>
#       <td id="T_ae572_row5_col1" class="data row5 col1" >1276</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ae572_row6_col0" class="data row6 col0" >India</td>
#       <td id="T_ae572_row6_col1" class="data row6 col1" >1001</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ae572_row7_col0" class="data row7 col0" >Germany</td>
#       <td id="T_ae572_row7_col1" class="data row7 col1" >988</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ae572_row8_col0" class="data row8 col0" >Spain</td>
#       <td id="T_ae572_row8_col1" class="data row8 col1" >885</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ae572_row9_col0" class="data row9 col0" >Switzerland</td>
#       <td id="T_ae572_row9_col1" class="data row9 col1" >869</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ae572_row10_col0" class="data row10 col0" >Russia</td>
#       <td id="T_ae572_row10_col1" class="data row10 col1" >841</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ae572_row11_col0" class="data row11 col0" >Italy</td>
#       <td id="T_ae572_row11_col1" class="data row11 col1" >743</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ae572_row12_col0" class="data row12 col0" >New Zealand</td>
#       <td id="T_ae572_row12_col1" class="data row12 col1" >743</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ae572_row13_col0" class="data row13 col0" >S Korea</td>
#       <td id="T_ae572_row13_col1" class="data row13 col1" >593</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ae572_row14_col0" class="data row14 col0" >Austria</td>
#       <td id="T_ae572_row14_col1" class="data row14 col1" >591</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ae572_row15_col0" class="data row15 col0" >Poland</td>
#       <td id="T_ae572_row15_col1" class="data row15 col1" >463</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ae572_row16_col0" class="data row16 col0" >Australia</td>
#       <td id="T_ae572_row16_col1" class="data row16 col1" >392</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ae572_row17_col0" class="data row17 col0" >Canada</td>
#       <td id="T_ae572_row17_col1" class="data row17 col1" >329</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ae572_row18_col0" class="data row18 col0" >Netherlands</td>
#       <td id="T_ae572_row18_col1" class="data row18 col1" >294</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ae572_row19_col0" class="data row19 col0" >W Germany</td>
#       <td id="T_ae572_row19_col1" class="data row19 col1" >279</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ae572_row20_col0" class="data row20 col0" >Ukraine</td>
#       <td id="T_ae572_row20_col1" class="data row20 col1" >227</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ae572_row21_col0" class="data row21 col0" >Norway</td>
#       <td id="T_ae572_row21_col1" class="data row21 col1" >200</td>
#     </tr>
#     <tr>
#       <th id="T_ae572_level0_row22" class="row_heading level0 row22" >22</th>

# %%
df['year'] = df['year'].astype(int)

df['year_interval'] = (df['year'] // 5) * 5

df['total_success'] = (
    df[['success1', 'success2', 'success3', 'success4']]
    .map(lambda x: str(x).strip().upper() == 'TRUE')
    .sum(axis=1)
)

interval_success = df.groupby('year_interval')['total_success'].sum().reset_index()

interval_success.columns = ['5-Year Interval Start', 'Total Successful Summits']

styled_table = interval_success.style.background_gradient(
    subset=['Total Successful Summits'],
    cmap='YlGnBu'
).set_properties(**{'text-align': 'center'}).set_caption("Total Successful Summits in 5-Year Intervals")

styled_table
# Out:
# <style type="text/css">
# #T_880bd_row0_col0, #T_880bd_row1_col0, #T_880bd_row2_col0, #T_880bd_row3_col0, #T_880bd_row4_col0, #T_880bd_row5_col0, #T_880bd_row6_col0, #T_880bd_row7_col0, #T_880bd_row8_col0, #T_880bd_row9_col0, #T_880bd_row10_col0, #T_880bd_row11_col0, #T_880bd_row12_col0, #T_880bd_row13_col0, #T_880bd_row14_col0, #T_880bd_row15_col0, #T_880bd_row16_col0, #T_880bd_row17_col0, #T_880bd_row18_col0, #T_880bd_row19_col0, #T_880bd_row20_col0, #T_880bd_row21_col0, #T_880bd_row22_col0 {
#   text-align: center;
# }
# #T_880bd_row0_col1, #T_880bd_row1_col1, #T_880bd_row2_col1, #T_880bd_row3_col1, #T_880bd_row4_col1, #T_880bd_row6_col1, #T_880bd_row7_col1 {
#   background-color: #ffffd9;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row5_col1 {
#   background-color: #feffd8;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row8_col1 {
#   background-color: #fcfed1;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row9_col1 {
#   background-color: #fbfdd0;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row10_col1 {
#   background-color: #f7fcc7;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row11_col1 {
#   background-color: #fdfed5;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row12_col1 {
#   background-color: #f5fbc2;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row13_col1 {
#   background-color: #f1faba;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row14_col1 {
#   background-color: #cbebb4;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row15_col1 {
#   background-color: #bbe4b5;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row16_col1 {
#   background-color: #80cebb;
#   color: #000000;
#   text-align: center;
# }
# #T_880bd_row17_col1 {
#   background-color: #46b8c3;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_880bd_row18_col1 {
#   background-color: #2165ab;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_880bd_row19_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_880bd_row20_col1 {
#   background-color: #0f2367;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_880bd_row21_col1 {
#   background-color: #091e5a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_880bd_row22_col1 {
#   background-color: #2195c0;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_880bd">
#   <caption>Total Successful Summits in 5-Year Intervals</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_880bd_level0_col0" class="col_heading level0 col0" >5-Year Interval Start</th>
#       <th id="T_880bd_level0_col1" class="col_heading level0 col1" >Total Successful Summits</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_880bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_880bd_row0_col0" class="data row0 col0" >1905</td>
#       <td id="T_880bd_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_880bd_row1_col0" class="data row1 col0" >1910</td>
#       <td id="T_880bd_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_880bd_row2_col0" class="data row2 col0" >1920</td>
#       <td id="T_880bd_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_880bd_row3_col0" class="data row3 col0" >1925</td>
#       <td id="T_880bd_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_880bd_row4_col0" class="data row4 col0" >1930</td>
#       <td id="T_880bd_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_880bd_row5_col0" class="data row5 col0" >1935</td>
#       <td id="T_880bd_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_880bd_row6_col0" class="data row6 col0" >1940</td>
#       <td id="T_880bd_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_880bd_row7_col0" class="data row7 col0" >1945</td>
#       <td id="T_880bd_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_880bd_row8_col0" class="data row8 col0" >1950</td>
#       <td id="T_880bd_row8_col1" class="data row8 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_880bd_row9_col0" class="data row9 col0" >1955</td>
#       <td id="T_880bd_row9_col1" class="data row9 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_880bd_row10_col0" class="data row10 col0" >1960</td>
#       <td id="T_880bd_row10_col1" class="data row10 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_880bd_row11_col0" class="data row11 col0" >1965</td>
#       <td id="T_880bd_row11_col1" class="data row11 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_880bd_row12_col0" class="data row12 col0" >1970</td>
#       <td id="T_880bd_row12_col1" class="data row12 col1" >78</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_880bd_row13_col0" class="data row13 col0" >1975</td>
#       <td id="T_880bd_row13_col1" class="data row13 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_880bd_row14_col0" class="data row14 col0" >1980</td>
#       <td id="T_880bd_row14_col1" class="data row14 col1" >256</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_880bd_row15_col0" class="data row15 col0" >1985</td>
#       <td id="T_880bd_row15_col1" class="data row15 col1" >294</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_880bd_row16_col0" class="data row16 col0" >1990</td>
#       <td id="T_880bd_row16_col1" class="data row16 col1" >402</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_880bd_row17_col0" class="data row17 col0" >1995</td>
#       <td id="T_880bd_row17_col1" class="data row17 col1" >530</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_880bd_row18_col0" class="data row18 col0" >2000</td>
#       <td id="T_880bd_row18_col1" class="data row18 col1" >788</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_880bd_row19_col0" class="data row19 col0" >2005</td>
#       <td id="T_880bd_row19_col1" class="data row19 col1" >1078</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_880bd_row20_col0" class="data row20 col0" >2010</td>
#       <td id="T_880bd_row20_col1" class="data row20 col1" >1042</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_880bd_row21_col0" class="data row21 col0" >2015</td>
#       <td id="T_880bd_row21_col1" class="data row21 col1" >1072</td>
#     </tr>
#     <tr>
#       <th id="T_880bd_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_880bd_row22_col0" class="data row22 col0" >2020</td>
#       <td id="T_880bd_row22_col1" class="data row22 col1" >658</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Normalize success columns to boolean
for col in ['success1', 'success2', 'success3', 'success4']:
    df[col] = df[col].astype(str).str.strip().str.upper() == 'TRUE'

# One expedition is considered a success if any success is True
df['exp_success'] = df[['success1', 'success2', 'success3', 'success4']].any(axis=1).astype(int)
df['exp_failure'] = (~df[['success1', 'success2', 'success3', 'success4']].any(axis=1)).astype(int)

# Group by nation and calculate total success/failure
nation_stats = df.groupby('nation').agg({
    'exp_success': 'sum',
    'exp_failure': 'sum'
}).reset_index()

# Compute success/failure ratio
nation_stats['success_failure_ratio'] = nation_stats['exp_success'] / nation_stats['exp_failure'].replace(0, pd.NA)

# Sort by ratio
nation_stats = nation_stats.sort_values(by='success_failure_ratio', ascending=False)

# Apply gradient style
styled_table = nation_stats.style.background_gradient(
    subset=['success_failure_ratio'],
    cmap='Greens'
).format({
    'exp_success': '{:.0f}',
    'exp_failure': '{:.0f}',
    'success_failure_ratio': '{:.2f}'
}).set_caption("Expedition-Level Success/Failure Ratio by Nation")

styled_table
# Out:
# <style type="text/css">
# #T_ca07c_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ca07c_row1_col3 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_ca07c_row2_col3 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_ca07c_row3_col3 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_ca07c_row4_col3 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_ca07c_row5_col3, #T_ca07c_row6_col3 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_ca07c_row7_col3, #T_ca07c_row8_col3 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_ca07c_row9_col3 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_ca07c_row10_col3 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_ca07c_row11_col3 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_ca07c_row12_col3, #T_ca07c_row13_col3 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_ca07c_row14_col3 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_ca07c_row15_col3 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_ca07c_row16_col3, #T_ca07c_row17_col3 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_ca07c_row18_col3, #T_ca07c_row19_col3, #T_ca07c_row20_col3 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_ca07c_row21_col3 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_ca07c_row22_col3 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_ca07c_row23_col3 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_ca07c_row24_col3, #T_ca07c_row25_col3 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_ca07c_row26_col3, #T_ca07c_row27_col3 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_ca07c_row28_col3 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_ca07c_row29_col3 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_ca07c_row30_col3, #T_ca07c_row31_col3, #T_ca07c_row32_col3, #T_ca07c_row33_col3 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_ca07c_row34_col3, #T_ca07c_row35_col3 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_ca07c_row36_col3 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_ca07c_row37_col3 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_ca07c_row38_col3 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_ca07c_row39_col3 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_ca07c_row40_col3 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_ca07c_row41_col3 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_ca07c_row42_col3 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_ca07c_row43_col3 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_ca07c_row44_col3, #T_ca07c_row45_col3, #T_ca07c_row46_col3 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_ca07c_row47_col3, #T_ca07c_row48_col3 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_ca07c_row49_col3, #T_ca07c_row50_col3, #T_ca07c_row51_col3, #T_ca07c_row52_col3, #T_ca07c_row53_col3, #T_ca07c_row54_col3, #T_ca07c_row55_col3, #T_ca07c_row56_col3, #T_ca07c_row57_col3, #T_ca07c_row58_col3 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_ca07c_row59_col3, #T_ca07c_row60_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_ca07c_row61_col3 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_ca07c_row62_col3, #T_ca07c_row63_col3 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_ca07c_row64_col3 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_ca07c_row65_col3 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_ca07c_row66_col3 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_ca07c_row67_col3 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_ca07c_row68_col3 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_ca07c_row69_col3 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_ca07c_row70_col3 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_ca07c_row71_col3, #T_ca07c_row72_col3, #T_ca07c_row73_col3 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_ca07c_row74_col3 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_ca07c_row75_col3 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_ca07c_row76_col3, #T_ca07c_row77_col3, #T_ca07c_row78_col3, #T_ca07c_row79_col3, #T_ca07c_row80_col3, #T_ca07c_row81_col3, #T_ca07c_row82_col3, #T_ca07c_row83_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_ca07c_row84_col3, #T_ca07c_row85_col3, #T_ca07c_row86_col3, #T_ca07c_row87_col3, #T_ca07c_row88_col3, #T_ca07c_row89_col3, #T_ca07c_row90_col3, #T_ca07c_row91_col3, #T_ca07c_row92_col3, #T_ca07c_row93_col3, #T_ca07c_row94_col3, #T_ca07c_row95_col3, #T_ca07c_row96_col3, #T_ca07c_row97_col3, #T_ca07c_row98_col3, #T_ca07c_row99_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ca07c">
#   <caption>Expedition-Level Success/Failure Ratio by Nation</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca07c_level0_col0" class="col_heading level0 col0" >nation</th>
#       <th id="T_ca07c_level0_col1" class="col_heading level0 col1" >exp_success</th>
#       <th id="T_ca07c_level0_col2" class="col_heading level0 col2" >exp_failure</th>
#       <th id="T_ca07c_level0_col3" class="col_heading level0 col3" >success_failure_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca07c_level0_row0" class="row_heading level0 row0" >45</th>
#       <td id="T_ca07c_row0_col0" class="data row0 col0" >Kazakhstan</td>
#       <td id="T_ca07c_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_ca07c_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_ca07c_row0_col3" class="data row0 col3" >5.50</td>
#     </tr>
#     <tr>
#       <th id="T_ca07c_level0_row1" class="row_heading level0 row1" >91</th>
#       <td id="T_ca07c_row1_col0" class="data row1 col0" >USSR</td>
#       <td id="T_ca07c_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_ca07c_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_ca07c_row1_col3" class="data row1 col3" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca07c_level0_row2" class="row_heading level0 row2" >18</th>
#       <td id="T_ca07c_row2_col0" class="data row2 col0" >China</td>
#       <td id="T_ca07c_row2_col1" class="data row2 col1" >182</td>
#       <td id="T_ca07c_row2_col2" class="data row2 col2" >45</td>
#       <td id="T_ca07c_row2_col3" class="data row2 col3" >4.04</td>
#     </tr>
#     <tr>
#       <th id="T_ca07c_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_ca07c_row3_col0" class="data row3 col0" >Kyrgyz Republic</td>
#       <td id="T_ca07c_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_ca07c_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_ca07c_row3_col3" class="data row3 col3" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca07c_level0_row4" class="row_heading level0 row4" >59</th>
#       <td id="T_ca07c_row4_col0" class="data row4 col0" >Nepal</td>
#       <td id="T_ca07c_row4_col1" class="data row4 col1" >303</td>
#       <td id="T_ca07c_row4_col2" class="data row4 col2" >84</td>
#       <td id="T_ca07c_row4_col3" class="data row4 col3" >3.61</td>
#     </tr>
#     <tr>
#       <th id="T_ca07c_level0_row5" class="row_heading level0 row5" >20</th>
#       <td id="T_ca07c_row5_col0" class="data row5 col0" >Croatia</td>
#       <td id="T_ca07c_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_ca07c_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_ca07c_row5_col3" class="data row5 col3" >3.50</td>
#     </tr>
#     <tr>
#       <th id="T_ca07c_level0_row6" class="row_heading level0 row6" >57</th>
#       <td id="T_ca07c_row6_col0" class="data row6 col0" >Mongolia</td>
#       <td id="T_ca07c_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_ca07c_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_ca07c_row6_col3" class="data row6 col3" >3.50</td>
#     </tr>
#     <tr>
#       <th id="T_ca07c_level0_row7" class="row_heading level0 row7" >49</th>
#       <td id="T_ca07c_row7_col0" class="data row7 col0" >Latvia</td>
#       <td id="T_ca07c_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_ca07c_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_ca07c_row7_col3"
